# %%
import matplotlib.pyplot as plt
Depth =[0,8,10,19,20,30,39,50,58,75,78,100]
Temp =[10.5,10.46,10.46,10.45,10.45,10.45,10.45,10.24,10.06,9.86,9.83,9.67]

plt.title ('Linear Regression')
plt.grid()
plt.scatter (Depth,Temp)
plt.xlabel ('Depth(m)')
plt.ylabel ('Temp(C)')
plt.show()
